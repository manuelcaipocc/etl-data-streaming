# %% [markdown]
# # Connection Ctrl X - OPC UA

# %%
from opcua import Client

# OPC UA server address
url = "opc.tcp://ctrlX-CORE:4840"  # Replace with your CtrlX IP
url = "opc.tcp://192.168.1.1:4840" # Both work
client = Client(url)

client.set_user("boschrexroth")
client.set_password("Boschrexroth1")

try:
    client.connect()
    print("Connected to the OPC UA server")

    root_node = client.get_root_node()
    print("Root Node:", root_node)

    variable_node = client.get_node("ns=2;s=plc/app/Application/sym/GVL_TemplateGlobal/fbcAxis1_ActValues_gb/fbHA_FilterVel/arBuffer/92")
    value = variable_node.get_value()
    print("Value read:", value)

    variable_node.set_value(42) 
    print("Value written successfully")

except Exception as e:
    print("Error connecting to or communicating with the OPC UA server:", e)

finally:
    client.disconnect()
    print("Disconnected from the OPC UA server")
# Out:
# Connected to the OPC UA server
# Root Node: i=84
# Value read: 0
# Value written successfully
# Disconnected from the OPC UA server

# %% [markdown]
# # Testing and evaluating datatypes

# %%
from opcua import Client, ua
import time

# Define your list of nodes (simplified to only include NodeId and BrowseName)
nodes = [
    {"NodeId": "ns=2;s=plc/app/Application/sym/GVL_HMI/P_s", "BrowseName": "P_s"},
    {"NodeId": "ns=2;s=plc/app/Application/sym/GVL_HMI/P_a", "BrowseName": "P_a"},
    {"NodeId": "ns=2;s=plc/app/Application/sym/GVL_HMI/P_b", "BrowseName": "P_b"},
    {"NodeId": "ns=2;s=plc/app/Application/sym/GVL_HMI/V", "BrowseName": "V"},
    {"NodeId": "ns=2;s=plc/app/Application/sym/GVL_HMI/ACT_Pos", "BrowseName": "ACT_Pos"},
    {"NodeId": "ns=2;s=plc/app/Application/sym/GVL_HMI/ACT_Vel", "BrowseName": "ACT_Vel"},
    {"NodeId": "ns=2;s=plc/app/Application/sym/GVL_HMI/Eff_hyd", "BrowseName": "Eff_hyd"},
    {"NodeId": "ns=2;s=plc/app/Application/sym/GVL_HMI/Eff_mech", "BrowseName": "Eff_mech"},
    {"NodeId": "ns=2;s=plc/app/Application/sym/GVL_HMI/Eff_syst", "BrowseName": "Eff_syst"},
    {"NodeId": "ns=2;s=plc/app/Application/sym/GVL_HMI/P_mech", "BrowseName": "P_mech"},
    {"NodeId": "ns=2;s=plc/app/Application/sym/GVL_HMI/Q", "BrowseName": "Q"},
    {"NodeId": "ns=2;s=plc/app/Application/sym/GLV_IO/rEnergiemonitoring_I1_i", "BrowseName": "rEnergiemonitoring_I1_i"},
    {"NodeId": "ns=2;s=plc/app/Application/sym/GLV_IO/rEnergiemonitoring_U1_i", "BrowseName": "rEnergiemonitoring_U1_i"},
    {"NodeId": "ns=2;s=plc/app/Application/sym/GLV_IO/bDigiOut_XG1_OutA_q", "BrowseName": "bDigiOut_XG1_OutA_q"},
    {"NodeId": "ns=2;s=plc/app/Application/sym/GVL_HMI/bHMI_Status_DigiOut_XG1_OutA_gb", "BrowseName": "bHMI_Status_DigiOut_XG1_OutA_gb"},
    {"NodeId": "ns=2;s=plc/app/Application/sym/GVL_HMI/bHMI_Steuern_DigiOut_XG1_OutA_gb", "BrowseName": "bHMI_Steuern_DigiOut_XG1_OutA_gb"}
]

# OPC UA server connection
url = "opc.tcp://192.168.1.1:4840"
client = Client(url)

# Optional: User and password (if required by server)
client.set_user("boschrexroth")
client.set_password("Boschrexroth1")

try:
    client.connect()
    print("Connected to OPC UA server")

    for node_info in nodes:
        node_id_str = node_info["NodeId"]
        browse_name = node_info.get("BrowseName", "Unnamed")

        print(f"\nChecking node: {browse_name} ({node_id_str})")
        try:
            node = client.get_node(node_id_str)
            value = node.get_value()
            print(f"Current value: {value}")
        except ua.UaError as ua_error:
            print(f"OPC UA error accessing node: {ua_error}")
        except Exception as e:
            print(f"Error accessing node: {e}")

except Exception as e:
    print("Error connecting to OPC UA server:", e)

finally:
    client.disconnect()
    print("\nDisconnected from OPC UA server")
# Out:
# Connected to OPC UA server
#
# Checking node: P_s (ns=2;s=plc/app/Application/sym/GVL_HMI/P_s)
# Current value: 0.0
#
# Checking node: P_a (ns=2;s=plc/app/Application/sym/GVL_HMI/P_a)
# Current value: 0.3125
#
# Checking node: P_b (ns=2;s=plc/app/Application/sym/GVL_HMI/P_b)
# Current value: 0.0
#
# Checking node: V (ns=2;s=plc/app/Application/sym/GVL_HMI/V)
# Current value: 232.35162353515625
#
# Checking node: ACT_Pos (ns=2;s=plc/app/Application/sym/GVL_HMI/ACT_Pos)
# Current value: 379.0511169433594
#
# Checking node: ACT_Vel (ns=2;s=plc/app/Application/sym/GVL_HMI/ACT_Vel)
# Current value: -0.03832000121474266
#
# Checking node: Eff_hyd (ns=2;s=plc/app/Application/sym/GVL_HMI/Eff_hyd)
# Current value: nan
#
# Checking node: Eff_mech (ns=2;s=plc/app/Application/sym/GVL_HMI/Eff_mech)
# Current value: inf
#
# Checking node: Eff_syst (ns=2;s=plc/app/Application/sym/GVL_HMI/Eff_syst)
# Current value: inf
#
# Checking node: P_mech (ns=2;s=plc/app/Application/sym/GVL_HMI/P_mech)
# Current value: 1.6374853657907806e-05
#
# Checking node: Q (ns=2;s=plc/app/Application/sym/GVL_HMI/Q)
# Current value: 0.0018749999580904841
#
# Checking node: rEnergiemonitoring_I1_i (ns=2;s=plc/app/Application/sym/GLV_IO/rEnergiemonitoring_I1_i)
# Current value: 0.0
#
# Checking node: rEnergiemonitoring_U1_i (ns=2;s=plc/app/Application/sym/GLV_IO/rEnergiemonitoring_U1_i)
# Current value: 232.35162353515625
#
# Checking node: bDigiOut_XG1_OutA_q (ns=2;s=plc/app/Application/sym/GLV_IO/bDigiOut_XG1_OutA_q)
# OPC UA error accessing node: "Requested operation is not implemented."(BadNotImplemented)
#
# Checking node: bHMI_Status_DigiOut_XG1_OutA_gb (ns=2;s=plc/app/Application/sym/GVL_HMI/bHMI_Status_DigiOut_XG1_OutA_gb)
# Current value: False
#
# Checking node: bHMI_Steuern_DigiOut_XG1_OutA_gb (ns=2;s=plc/app/Application/sym/GVL_HMI/bHMI_Steuern_DigiOut_XG1_OutA_gb)
# Current value: False
#
# Disconnected from OPC UA server

# %% [markdown]
# # Extraction of nodes CtrlX- OPCUA

# %%
from opcua import Client
import json

# OPC UA server address
url = "opc.tcp://192.168.1.20:4840"  # Replace with your CtrlX IP address
client = Client(url)

# Optional credentials (required for your system)
client.set_user("boschrexroth")
client.set_password("boschrexroth")

# List to store explored nodes
nodes_list = []

def explore_node(node, level=0):
    """
    Recursive function to explore a node and its children.
    """
    try:
        indent = "  " * level  # Indentation to show hierarchy
        browse_name = node.get_browse_name()
        node_id = node.nodeid

        # Save the node to the list
        nodes_list.append({
            "NodeId": str(node_id),
            "BrowseName": str(browse_name),
            "Level": level
        })

        print(f"{indent}- Node: {node}, BrowseName: {browse_name}")

        # Get child nodes
        children = node.get_children()
        for child in children:
            explore_node(child, level + 1)
    except Exception as e:
        print(f"{indent}Error exploring node: {e}")

try:
    # Connect to the OPC UA server
    client.connect()
    print("Connected to OPC UA server")

    # Get root node
    root_node = client.get_root_node()
    print("Root Node:", root_node)

    # Explore the root node
    print("Exploring node tree...")
    explore_node(root_node)

    # Sort the found nodes by level and name
    nodes_list.sort(key=lambda x: (x["Level"], x["BrowseName"]))

    # Display the sorted node list
    print("\nSorted node list:")
    for node_info in nodes_list:
        print(f"Level: {node_info['Level']}, BrowseName: {node_info['BrowseName']}, NodeId: {node_info['NodeId']}")

    # Save the node list to a JSON file
    with open("nodos_opcua_LR3.json", "w", encoding="utf-8") as file:
        json.dump(nodes_list, file, ensure_ascii=False, indent=4)
    print("\nNode list has been saved to 'nodos_opcua.json'.")

except Exception as e:
    print("Error connecting to or communicating with OPC UA server:", e)

finally:
    # Close the connection safely
    client.disconnect()
    print("Disconnected from OPC UA server")
# Out:
# Connected to OPC UA server
# Root Node: i=84
# Exploring node tree...
# - Node: i=84, BrowseName: QualifiedName(0:Root)
#   - Node: i=85, BrowseName: QualifiedName(0:Objects)
#     - Node: i=2253, BrowseName: QualifiedName(0:Server)
#       - Node: i=2254, BrowseName: QualifiedName(0:ServerArray)
#       - Node: i=2255, BrowseName: QualifiedName(0:NamespaceArray)
#       - Node: i=15004, BrowseName: QualifiedName(0:UrisVersion)
#       - Node: i=2256, BrowseName: QualifiedName(0:ServerStatus)
#         - Node: i=2257, BrowseName: QualifiedName(0:StartTime)
#         - Node: i=2258, BrowseName: QualifiedName(0:CurrentTime)
#         - Node: i=2259, BrowseName: QualifiedName(0:State)
#         - Node: i=2260, BrowseName: QualifiedName(0:BuildInfo)
#           - Node: i=2262, BrowseName: QualifiedName(0:ProductUri)
#           - Node: i=2263, BrowseName: QualifiedName(0:ManufacturerName)
#           - Node: i=2261, BrowseName: QualifiedName(0:ProductName)
#           - Node: i=2264, BrowseName: QualifiedName(0:SoftwareVersion)
#           - Node: i=2265, BrowseName: QualifiedName(0:BuildNumber)
#           - Node: i=2266, BrowseName: QualifiedName(0:BuildDate)
#         - Node: i=2992, BrowseName: QualifiedName(0:SecondsTillShutdown)
#         - Node: i=2993, BrowseName: QualifiedName(0:ShutdownReason)
#       - Node: i=2267, BrowseName: QualifiedName(0:ServiceLevel)
#       - Node: i=2994, BrowseName: QualifiedName(0:Auditing)
#       - Node: i=12885, BrowseName: QualifiedName(0:EstimatedReturnTime)
#       - Node: i=17634, BrowseName: QualifiedName(0:LocalTime)
#       - Node: i=2268, BrowseName: QualifiedName(0:ServerCapabilities)
#         - Node: i=2269, BrowseName: QualifiedName(0:ServerProfileArray)
#         - Node: i=2271, BrowseName: QualifiedName(0:LocaleIdArray)
#         - Node: i=2272, BrowseName: QualifiedName(0:MinSupportedSampleRate)
#         - Node: i=2735, BrowseName: QualifiedName(0:MaxBrowseContinuationPoints)
#         - Node: i=2736, BrowseName: QualifiedName(0:MaxQueryContinuationPoints)
#         - Node: i=2737, BrowseName: QualifiedName(0:MaxHistoryContinuationPoints)
#         - Node: i=3704, BrowseName: QualifiedName(0:SoftwareCertificates)
#         - Node: i=11702, BrowseName: QualifiedName(0:MaxArrayLength)
#         - Node: i=11703, BrowseName: QualifiedName(0:MaxStringLength)
#         - Node: i=12911, BrowseName: QualifiedName(0:MaxByteStringLength)
#         - Node: i=11704, BrowseName: QualifiedName(0:OperationLimits)
#           - Node: i=11705, BrowseName: QualifiedName(0:MaxNodesPerRead)
#           - Node: i=12165, BrowseName: QualifiedName(0:MaxNodesPerHistoryReadData)
#           - Node: i=12166, BrowseName: QualifiedName(0:MaxNodesPerHistoryReadEvents)
#           - Node: i=11707, BrowseName: QualifiedName(0:MaxNodesPerWrite)
#           - Node: i=12167, BrowseName: QualifiedName(0:MaxNodesPerHistoryUpdateData)
#           - Node: i=12168, BrowseName: QualifiedName(0:MaxNodesPerHistoryUpdateEvents)
#           - Node: i=11709, BrowseName: QualifiedName(0:MaxNodesPerMethodCall)
#           - Node: i=11710, BrowseName: QualifiedName(0:MaxNodesPerBrowse)
#           - Node: i=11711, BrowseName: QualifiedName(0:MaxNodesPerRegisterNodes)
#           - Node: i=11712, BrowseName: QualifiedName(0:MaxNodesPerTranslateBrowsePathsToNodeIds)
#           - Node: i=11713, BrowseName: QualifiedName(0:MaxNodesPerNodeManagement)
#           - Node: i=11714, BrowseName: QualifiedName(0:MaxMonitoredItemsPerCall)
#         - Node: i=2996, BrowseName: QualifiedName(0:ModellingRules)
#         - Node: i=2997, BrowseName: QualifiedName(0:AggregateFunctions)
#         - Node: i=15606, BrowseName: QualifiedName(0:RoleSet)
#           - Node: i=16301, BrowseName: QualifiedName(0:AddRole)
#             - Node: i=16302, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=16303, BrowseName: QualifiedName(0:OutputArguments)
#           - Node: i=16304, BrowseName: QualifiedName(0:RemoveRole)
#             - Node: i=16305, BrowseName: QualifiedName(0:InputArguments)
#           - Node: i=15644, BrowseName: QualifiedName(0:Anonymous)
#             - Node: i=16192, BrowseName: QualifiedName(0:Identities)
#             - Node: i=15412, BrowseName: QualifiedName(0:ApplicationsExclude)
#             - Node: i=16193, BrowseName: QualifiedName(0:Applications)
#             - Node: i=15413, BrowseName: QualifiedName(0:EndpointsExclude)
#             - Node: i=16194, BrowseName: QualifiedName(0:Endpoints)
#             - Node: i=15648, BrowseName: QualifiedName(0:AddIdentity)
#               - Node: i=15649, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=15650, BrowseName: QualifiedName(0:RemoveIdentity)
#               - Node: i=15651, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=16195, BrowseName: QualifiedName(0:AddApplication)
#               - Node: i=16196, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=16197, BrowseName: QualifiedName(0:RemoveApplication)
#               - Node: i=16198, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=16199, BrowseName: QualifiedName(0:AddEndpoint)
#               - Node: i=16200, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=16201, BrowseName: QualifiedName(0:RemoveEndpoint)
#               - Node: i=16202, BrowseName: QualifiedName(0:InputArguments)
#           - Node: i=15656, BrowseName: QualifiedName(0:AuthenticatedUser)
#             - Node: i=16203, BrowseName: QualifiedName(0:Identities)
#             - Node: i=15414, BrowseName: QualifiedName(0:ApplicationsExclude)
#             - Node: i=16204, BrowseName: QualifiedName(0:Applications)
#             - Node: i=15415, BrowseName: QualifiedName(0:EndpointsExclude)
#             - Node: i=16205, BrowseName: QualifiedName(0:Endpoints)
#             - Node: i=24141, BrowseName: QualifiedName(0:CustomConfiguration)
#             - Node: i=15660, BrowseName: QualifiedName(0:AddIdentity)
#               - Node: i=15661, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=15662, BrowseName: QualifiedName(0:RemoveIdentity)
#               - Node: i=15663, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=16206, BrowseName: QualifiedName(0:AddApplication)
#               - Node: i=16207, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=16208, BrowseName: QualifiedName(0:RemoveApplication)
#               - Node: i=16209, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=16210, BrowseName: QualifiedName(0:AddEndpoint)
#               - Node: i=16211, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=16212, BrowseName: QualifiedName(0:RemoveEndpoint)
#               - Node: i=16213, BrowseName: QualifiedName(0:InputArguments)
#           - Node: i=15668, BrowseName: QualifiedName(0:Observer)
#             - Node: i=16214, BrowseName: QualifiedName(0:Identities)
#             - Node: i=15416, BrowseName: QualifiedName(0:ApplicationsExclude)
#             - Node: i=16215, BrowseName: QualifiedName(0:Applications)
#             - Node: i=15417, BrowseName: QualifiedName(0:EndpointsExclude)
#             - Node: i=16216, BrowseName: QualifiedName(0:Endpoints)
#             - Node: i=24142, BrowseName: QualifiedName(0:CustomConfiguration)
#             - Node: i=15672, BrowseName: QualifiedName(0:AddIdentity)
#               - Node: i=15673, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=15674, BrowseName: QualifiedName(0:RemoveIdentity)
#               - Node: i=15675, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=16217, BrowseName: QualifiedName(0:AddApplication)
#               - Node: i=16218, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=16219, BrowseName: QualifiedName(0:RemoveApplication)
#               - Node: i=16220, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=16221, BrowseName: QualifiedName(0:AddEndpoint)
#               - Node: i=16222, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=16223, BrowseName: QualifiedName(0:RemoveEndpoint)
#               - Node: i=16224, BrowseName: QualifiedName(0:InputArguments)
#           - Node: i=15680, BrowseName: QualifiedName(0:Operator)
#             - Node: i=16225, BrowseName: QualifiedName(0:Identities)
#             - Node: i=15418, BrowseName: QualifiedName(0:ApplicationsExclude)
#             - Node: i=16226, BrowseName: QualifiedName(0:Applications)
#             - Node: i=15423, BrowseName: QualifiedName(0:EndpointsExclude)
#             - Node: i=16227, BrowseName: QualifiedName(0:Endpoints)
#             - Node: i=24143, BrowseName: QualifiedName(0:CustomConfiguration)
#             - Node: i=15684, BrowseName: QualifiedName(0:AddIdentity)
#               - Node: i=15685, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=15686, BrowseName: QualifiedName(0:RemoveIdentity)
#               - Node: i=15687, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=16228, BrowseName: QualifiedName(0:AddApplication)
#               - Node: i=16229, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=16230, BrowseName: QualifiedName(0:RemoveApplication)
#               - Node: i=16231, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=16232, BrowseName: QualifiedName(0:AddEndpoint)
#               - Node: i=16233, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=16234, BrowseName: QualifiedName(0:RemoveEndpoint)
#               - Node: i=16235, BrowseName: QualifiedName(0:InputArguments)
#           - Node: i=16036, BrowseName: QualifiedName(0:Engineer)
#             - Node: i=16236, BrowseName: QualifiedName(0:Identities)
#             - Node: i=15424, BrowseName: QualifiedName(0:ApplicationsExclude)
#             - Node: i=16237, BrowseName: QualifiedName(0:Applications)
#             - Node: i=15425, BrowseName: QualifiedName(0:EndpointsExclude)
#             - Node: i=16238, BrowseName: QualifiedName(0:Endpoints)
#             - Node: i=24144, BrowseName: QualifiedName(0:CustomConfiguration)
#             - Node: i=16041, BrowseName: QualifiedName(0:AddIdentity)
#               - Node: i=16042, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=16043, BrowseName: QualifiedName(0:RemoveIdentity)
#               - Node: i=16044, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=16239, BrowseName: QualifiedName(0:AddApplication)
#               - Node: i=16240, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=16241, BrowseName: QualifiedName(0:RemoveApplication)
#               - Node: i=16242, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=16243, BrowseName: QualifiedName(0:AddEndpoint)
#               - Node: i=16244, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=16245, BrowseName: QualifiedName(0:RemoveEndpoint)
#               - Node: i=16246, BrowseName: QualifiedName(0:InputArguments)
#           - Node: i=15692, BrowseName: QualifiedName(0:Supervisor)
#             - Node: i=16247, BrowseName: QualifiedName(0:Identities)
#             - Node: i=15426, BrowseName: QualifiedName(0:ApplicationsExclude)
#             - Node: i=16248, BrowseName: QualifiedName(0:Applications)
#             - Node: i=15427, BrowseName: QualifiedName(0:EndpointsExclude)
#             - Node: i=16249, BrowseName: QualifiedName(0:Endpoints)
#             - Node: i=24145, BrowseName: QualifiedName(0:CustomConfiguration)
#             - Node: i=15696, BrowseName: QualifiedName(0:AddIdentity)
#               - Node: i=15697, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=15698, BrowseName: QualifiedName(0:RemoveIdentity)
#               - Node: i=15699, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=16250, BrowseName: QualifiedName(0:AddApplication)
#               - Node: i=16251, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=16252, BrowseName: QualifiedName(0:RemoveApplication)
#               - Node: i=16253, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=16254, BrowseName: QualifiedName(0:AddEndpoint)
#               - Node: i=16255, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=16256, BrowseName: QualifiedName(0:RemoveEndpoint)
#               - Node: i=16257, BrowseName: QualifiedName(0:InputArguments)
#           - Node: i=15716, BrowseName: QualifiedName(0:ConfigureAdmin)
#             - Node: i=16269, BrowseName: QualifiedName(0:Identities)
#             - Node: i=15428, BrowseName: QualifiedName(0:ApplicationsExclude)
#             - Node: i=16270, BrowseName: QualifiedName(0:Applications)
#             - Node: i=15429, BrowseName: QualifiedName(0:EndpointsExclude)
#             - Node: i=16271, BrowseName: QualifiedName(0:Endpoints)
#             - Node: i=24146, BrowseName: QualifiedName(0:CustomConfiguration)
#             - Node: i=15720, BrowseName: QualifiedName(0:AddIdentity)
#               - Node: i=15721, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=15722, BrowseName: QualifiedName(0:RemoveIdentity)
#               - Node: i=15723, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=16272, BrowseName: QualifiedName(0:AddApplication)
#               - Node: i=16273, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=16274, BrowseName: QualifiedName(0:RemoveApplication)
#               - Node: i=16275, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=16276, BrowseName: QualifiedName(0:AddEndpoint)
#               - Node: i=16277, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=16278, BrowseName: QualifiedName(0:RemoveEndpoint)
#               - Node: i=16279, BrowseName: QualifiedName(0:InputArguments)
#           - Node: i=15704, BrowseName: QualifiedName(0:SecurityAdmin)
#             - Node: i=16258, BrowseName: QualifiedName(0:Identities)
#             - Node: i=15430, BrowseName: QualifiedName(0:ApplicationsExclude)
#             - Node: i=16259, BrowseName: QualifiedName(0:Applications)
#             - Node: i=15527, BrowseName: QualifiedName(0:EndpointsExclude)
#             - Node: i=16260, BrowseName: QualifiedName(0:Endpoints)
#             - Node: i=24147, BrowseName: QualifiedName(0:CustomConfiguration)
#             - Node: i=15708, BrowseName: QualifiedName(0:AddIdentity)
#               - Node: i=15709, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=15710, BrowseName: QualifiedName(0:RemoveIdentity)
#               - Node: i=15711, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=16261, BrowseName: QualifiedName(0:AddApplication)
#               - Node: i=16262, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=16263, BrowseName: QualifiedName(0:RemoveApplication)
#               - Node: i=16264, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=16265, BrowseName: QualifiedName(0:AddEndpoint)
#               - Node: i=16266, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=16267, BrowseName: QualifiedName(0:RemoveEndpoint)
#               - Node: i=16268, BrowseName: QualifiedName(0:InputArguments)
#           - Node: i=25565, BrowseName: QualifiedName(0:SecurityKeyServerAdmin)
#             - Node: i=25566, BrowseName: QualifiedName(0:Identities)
#             - Node: i=25567, BrowseName: QualifiedName(0:ApplicationsExclude)
#             - Node: i=25568, BrowseName: QualifiedName(0:Applications)
#             - Node: i=25569, BrowseName: QualifiedName(0:EndpointsExclude)
#             - Node: i=25570, BrowseName: QualifiedName(0:Endpoints)
#             - Node: i=25571, BrowseName: QualifiedName(0:CustomConfiguration)
#             - Node: i=25572, BrowseName: QualifiedName(0:AddIdentity)
#               - Node: i=25573, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=25574, BrowseName: QualifiedName(0:RemoveIdentity)
#               - Node: i=25575, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=25576, BrowseName: QualifiedName(0:AddApplication)
#               - Node: i=25577, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=25578, BrowseName: QualifiedName(0:RemoveApplication)
#               - Node: i=25579, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=25580, BrowseName: QualifiedName(0:AddEndpoint)
#               - Node: i=25581, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=25582, BrowseName: QualifiedName(0:RemoveEndpoint)
#               - Node: i=25583, BrowseName: QualifiedName(0:InputArguments)
#           - Node: i=25584, BrowseName: QualifiedName(0:SecurityKeyServer)
#             - Node: i=25585, BrowseName: QualifiedName(0:Identities)
#             - Node: i=25586, BrowseName: QualifiedName(0:ApplicationsExclude)
#             - Node: i=25587, BrowseName: QualifiedName(0:Applications)
#             - Node: i=25588, BrowseName: QualifiedName(0:EndpointsExclude)
#             - Node: i=25589, BrowseName: QualifiedName(0:Endpoints)
#             - Node: i=25590, BrowseName: QualifiedName(0:CustomConfiguration)
#             - Node: i=25591, BrowseName: QualifiedName(0:AddIdentity)
#               - Node: i=25592, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=25593, BrowseName: QualifiedName(0:RemoveIdentity)
#               - Node: i=25594, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=25595, BrowseName: QualifiedName(0:AddApplication)
#               - Node: i=25596, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=25597, BrowseName: QualifiedName(0:RemoveApplication)
#               - Node: i=25598, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=25599, BrowseName: QualifiedName(0:AddEndpoint)
#               - Node: i=25600, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=25601, BrowseName: QualifiedName(0:RemoveEndpoint)
#               - Node: i=25602, BrowseName: QualifiedName(0:InputArguments)
#           - Node: i=25603, BrowseName: QualifiedName(0:SecurityKeyAccess)
#             - Node: i=25604, BrowseName: QualifiedName(0:Identities)
#             - Node: i=25605, BrowseName: QualifiedName(0:ApplicationsExclude)
#             - Node: i=25606, BrowseName: QualifiedName(0:Applications)
#             - Node: i=25607, BrowseName: QualifiedName(0:EndpointsExclude)
#             - Node: i=25608, BrowseName: QualifiedName(0:Endpoints)
#             - Node: i=25609, BrowseName: QualifiedName(0:CustomConfiguration)
#             - Node: i=25610, BrowseName: QualifiedName(0:AddIdentity)
#               - Node: i=25611, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=25612, BrowseName: QualifiedName(0:RemoveIdentity)
#               - Node: i=25613, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=25614, BrowseName: QualifiedName(0:AddApplication)
#               - Node: i=25615, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=25616, BrowseName: QualifiedName(0:RemoveApplication)
#               - Node: i=25617, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=25618, BrowseName: QualifiedName(0:AddEndpoint)
#               - Node: i=25619, BrowseName: QualifiedName(0:InputArguments)
#             - Node: i=25620, BrowseName: QualifiedName(0:RemoveEndpoint)
#               - Node: i=25621, BrowseName: QualifiedName(0:InputArguments)
#         - Node: i=24095, BrowseName: QualifiedName(0:MaxSessions)
#         - Node: i=24096, BrowseName: QualifiedName(0:MaxSubscriptions)
#         - Node: i=24097, BrowseName: QualifiedName(0:MaxMonitoredItems)
#         - Node: i=24098, BrowseName: QualifiedName(0:MaxSubscriptionsPerSession)
#         - Node: i=24104, BrowseName: QualifiedName(0:MaxMonitoredItemsPerSubscription)
#         - Node: i=24099, BrowseName: QualifiedName(0:MaxSelectClauseParameters)
#         - Node: i=24100, BrowseName: QualifiedName(0:MaxWhereClauseParameters)
#         - Node: i=24101, BrowseName: QualifiedName(0:ConformanceUnits)
#         - Node: i=11192, BrowseName: QualifiedName(0:HistoryServerCapabilities)
#           - Node: i=11193, BrowseName: QualifiedName(0:AccessHistoryDataCapability)
#           - Node: i=11242, BrowseName: QualifiedName(0:AccessHistoryEventsCapability)
#           - Node: i=11273, BrowseName: QualifiedName(0:MaxReturnDataValues)
#           - Node: i=11274, BrowseName: QualifiedName(0:MaxReturnEventValues)
#           - Node: i=11196, BrowseName: QualifiedName(0:InsertDataCapability)
#           - Node: i=11197, BrowseName: QualifiedName(0:ReplaceDataCapability)
#           - Node: i=11198, BrowseName: QualifiedName(0:UpdateDataCapability)
#           - Node: i=11199, BrowseName: QualifiedName(0:DeleteRawCapability)
#           - Node: i=11200, BrowseName: QualifiedName(0:DeleteAtTimeCapability)
#           - Node: i=11281, BrowseName: QualifiedName(0:InsertEventCapability)
#           - Node: i=11282, BrowseName: QualifiedName(0:ReplaceEventCapability)
#           - Node: i=11283, BrowseName: QualifiedName(0:UpdateEventCapability)
#           - Node: i=11502, BrowseName: QualifiedName(0:DeleteEventCapability)
#           - Node: i=11275, BrowseName: QualifiedName(0:InsertAnnotationCapability)
#           - Node: i=11201, BrowseName: QualifiedName(0:AggregateFunctions)
#           - Node: i=19091, BrowseName: QualifiedName(0:ServerTimestampSupported)
#       - Node: i=2274, BrowseName: QualifiedName(0:ServerDiagnostics)
#         - Node: i=2275, BrowseName: QualifiedName(0:ServerDiagnosticsSummary)
#           - Node: i=2276, BrowseName: QualifiedName(0:ServerViewCount)
#           - Node: i=2277, BrowseName: QualifiedName(0:CurrentSessionCount)
#           - Node: i=2278, BrowseName: QualifiedName(0:CumulatedSessionCount)
#           - Node: i=2279, BrowseName: QualifiedName(0:SecurityRejectedSessionCount)
#           - Node: i=3705, BrowseName: QualifiedName(0:RejectedSessionCount)
#           - Node: i=2281, BrowseName: QualifiedName(0:SessionTimeoutCount)
#           - Node: i=2282, BrowseName: QualifiedName(0:SessionAbortCount)
#           - Node: i=2284, BrowseName: QualifiedName(0:PublishingIntervalCount)
#           - Node: i=2285, BrowseName: QualifiedName(0:CurrentSubscriptionCount)
#           - Node: i=2286, BrowseName: QualifiedName(0:CumulatedSubscriptionCount)
#           - Node: i=2287, BrowseName: QualifiedName(0:SecurityRejectedRequestsCount)
#           - Node: i=2288, BrowseName: QualifiedName(0:RejectedRequestsCount)
#         - Node: i=2290, BrowseName: QualifiedName(0:SubscriptionDiagnosticsArray)
#           - Node: ns=1;i=572, BrowseName: QualifiedName(1:17891329)
#             - Node: ns=1;i=573, BrowseName: QualifiedName(0:SessionId)
#             - Node: ns=1;i=574, BrowseName: QualifiedName(0:SubscriptionId)
#             - Node: ns=1;i=575, BrowseName: QualifiedName(0:Priority)
#             - Node: ns=1;i=576, BrowseName: QualifiedName(0:PublishingInterval)
#             - Node: ns=1;i=577, BrowseName: QualifiedName(0:MaxKeepAliveCount)
#             - Node: ns=1;i=578, BrowseName: QualifiedName(0:MaxLifetimeCount)
#             - Node: ns=1;i=579, BrowseName: QualifiedName(0:MaxNotificationsPerPublish)
#             - Node: ns=1;i=580, BrowseName: QualifiedName(0:PublishingEnabled)
#             - Node: ns=1;i=581, BrowseName: QualifiedName(0:ModifyCount)
#             - Node: ns=1;i=582, BrowseName: QualifiedName(0:EnableCount)
#             - Node: ns=1;i=583, BrowseName: QualifiedName(0:DisableCount)
#             - Node: ns=1;i=584, BrowseName: QualifiedName(0:RepublishRequestCount)
#             - Node: ns=1;i=585, BrowseName: QualifiedName(0:RepublishMessageRequestCount)
#             - Node: ns=1;i=586, BrowseName: QualifiedName(0:RepublishMessageCount)
#             - Node: ns=1;i=587, BrowseName: QualifiedName(0:TransferRequestCount)
#             - Node: ns=1;i=588, BrowseName: QualifiedName(0:TransferredToAltClientCount)
#             - Node: ns=1;i=589, BrowseName: QualifiedName(0:TransferredToSameClientCount)
#             - Node: ns=1;i=590, BrowseName: QualifiedName(0:PublishRequestCount)
#             - Node: ns=1;i=591, BrowseName: QualifiedName(0:DataChangeNotificationsCount)
#             - Node: ns=1;i=592, BrowseName: QualifiedName(0:EventNotificationsCount)
#             - Node: ns=1;i=593, BrowseName: QualifiedName(0:NotificationsCount)
#             - Node: ns=1;i=594, BrowseName: QualifiedName(0:LatePublishRequestCount)
#             - Node: ns=1;i=595, BrowseName: QualifiedName(0:CurrentKeepAliveCount)
#             - Node: ns=1;i=596, BrowseName: QualifiedName(0:CurrentLifetimeCount)
#             - Node: ns=1;i=597, BrowseName: QualifiedName(0:UnacknowledgedMessageCount)
#             - Node: ns=1;i=598, BrowseName: QualifiedName(0:DiscardedMessageCount)
#             - Node: ns=1;i=599, BrowseName: QualifiedName(0:MonitoredItemCount)
#             - Node: ns=1;i=600, BrowseName: QualifiedName(0:DisabledMonitoredItemCount)
#             - Node: ns=1;i=601, BrowseName: QualifiedName(0:MonitoringQueueOverflowCount)
#             - Node: ns=1;i=602, BrowseName: QualifiedName(0:NextSequenceNumber)
#             - Node: ns=1;i=603, BrowseName: QualifiedName(0:EventQueueOverflowCount)
#           - Node: ns=1;i=828, BrowseName: QualifiedName(1:34668546)
#             - Node: ns=1;i=829, BrowseName: QualifiedName(0:SessionId)
#             - Node: ns=1;i=830, BrowseName: QualifiedName(0:SubscriptionId)
#             - Node: ns=1;i=831, BrowseName: QualifiedName(0:Priority)
#             - Node: ns=1;i=832, BrowseName: QualifiedName(0:PublishingInterval)
#             - Node: ns=1;i=833, BrowseName: QualifiedName(0:MaxKeepAliveCount)
#             - Node: ns=1;i=834, BrowseName: QualifiedName(0:MaxLifetimeCount)
#             - Node: ns=1;i=835, BrowseName: QualifiedName(0:MaxNotificationsPerPublish)
#             - Node: ns=1;i=836, BrowseName: QualifiedName(0:PublishingEnabled)
#             - Node: ns=1;i=837, BrowseName: QualifiedName(0:ModifyCount)
#             - Node: ns=1;i=838, BrowseName: QualifiedName(0:EnableCount)
#             - Node: ns=1;i=839, BrowseName: QualifiedName(0:DisableCount)
#             - Node: ns=1;i=840, BrowseName: QualifiedName(0:RepublishRequestCount)
#             - Node: ns=1;i=841, BrowseName: QualifiedName(0:RepublishMessageRequestCount)
#             - Node: ns=1;i=842, BrowseName: QualifiedName(0:RepublishMessageCount)
#             - Node: ns=1;i=843, BrowseName: QualifiedName(0:TransferRequestCount)
#             - Node: ns=1;i=844, BrowseName: QualifiedName(0:TransferredToAltClientCount)
#             - Node: ns=1;i=845, BrowseName: QualifiedName(0:TransferredToSameClientCount)
#             - Node: ns=1;i=846, BrowseName: QualifiedName(0:PublishRequestCount)
#             - Node: ns=1;i=847, BrowseName: QualifiedName(0:DataChangeNotificationsCount)
#             - Node: ns=1;i=848, BrowseName: QualifiedName(0:EventNotificationsCount)
#             - Node: ns=1;i=849, BrowseName: QualifiedName(0:NotificationsCount)
#             - Node: ns=1;i=850, BrowseName: QualifiedName(0:LatePublishRequestCount)
#             - Node: ns=1;i=851, BrowseName: QualifiedName(0:CurrentKeepAliveCount)
#             - Node: ns=1;i=852, BrowseName: QualifiedName(0:CurrentLifetimeCount)
#             - Node: ns=1;i=853, BrowseName: QualifiedName(0:UnacknowledgedMessageCount)
#             - Node: ns=1;i=854, BrowseName: QualifiedName(0:DiscardedMessageCount)
#             - Node: ns=1;i=855, BrowseName: QualifiedName(0:MonitoredItemCount)
#             - Node: ns=1;i=856, BrowseName: QualifiedName(0:DisabledMonitoredItemCount)
#             - Node: ns=1;i=857, BrowseName: QualifiedName(0:MonitoringQueueOverflowCount)
#             - Node: ns=1;i=858, BrowseName: QualifiedName(0:NextSequenceNumber)
#             - Node: ns=1;i=859, BrowseName: QualifiedName(0:EventQueueOverflowCount)
#           - Node: ns=1;i=1084, BrowseName: QualifiedName(1:18022403)
#             - Node: ns=1;i=1085, BrowseName: QualifiedName(0:SessionId)
#             - Node: ns=1;i=1086, BrowseName: QualifiedName(0:SubscriptionId)
#             - Node: ns=1;i=1087, BrowseName: QualifiedName(0:Priority)
#             - Node: ns=1;i=1088, BrowseName: QualifiedName(0:PublishingInterval)
#             - Node: ns=1;i=1089, BrowseName: QualifiedName(0:MaxKeepAliveCount)
#             - Node: ns=1;i=1090, BrowseName: QualifiedName(0:MaxLifetimeCount)
#             - Node: ns=1;i=1091, BrowseName: QualifiedName(0:MaxNotificationsPerPublish)
#             - Node: ns=1;i=1092, BrowseName: QualifiedName(0:PublishingEnabled)
#             - Node: ns=1;i=1093, BrowseName: QualifiedName(0:ModifyCount)
#             - Node: ns=1;i=1094, BrowseName: QualifiedName(0:EnableCount)
#             - Node: ns=1;i=1095, BrowseName: QualifiedName(0:DisableCount)
#             - Node: ns=1;i=1096, BrowseName: QualifiedName(0:RepublishRequestCount)
#             - Node: ns=1;i=1097, BrowseName: QualifiedName(0:RepublishMessageRequestCount)
#             - Node: ns=1;i=1098, BrowseName: QualifiedName(0:RepublishMessageCount)
#             - Node: ns=1;i=1099, BrowseName: QualifiedName(0:TransferRequestCount)
#             - Node: ns=1;i=1100, BrowseName: QualifiedName(0:TransferredToAltClientCount)
#             - Node: ns=1;i=1101, BrowseName: QualifiedName(0:TransferredToSameClientCount)
#             - Node: ns=1;i=1102, BrowseName: QualifiedName(0:PublishRequestCount)
#             - Node: ns=1;i=1103, BrowseName: QualifiedName(0:DataChangeNotificationsCount)
#             - Node: ns=1;i=1104, BrowseName: QualifiedName(0:EventNotificationsCount)
#             - Node: ns=1;i=1105, BrowseName: QualifiedName(0:NotificationsCount)
#             - Node: ns=1;i=1106, BrowseName: QualifiedName(0:LatePublishRequestCount)
#             - Node: ns=1;i=1107, BrowseName: QualifiedName(0:CurrentKeepAliveCount)
#             - Node: ns=1;i=1108, BrowseName: QualifiedName(0:CurrentLifetimeCount)
#             - Node: ns=1;i=1109, BrowseName: QualifiedName(0:UnacknowledgedMessageCount)
#             - Node: ns=1;i=1110, BrowseName: QualifiedName(0:DiscardedMessageCount)
#             - Node: ns=1;i=1111, BrowseName: QualifiedName(0:MonitoredItemCount)
#             - Node: ns=1;i=1112, BrowseName: QualifiedName(0:DisabledMonitoredItemCount)
#             - Node: ns=1;i=1113, BrowseName: QualifiedName(0:MonitoringQueueOverflowCount)
#             - Node: ns=1;i=1114, BrowseName: QualifiedName(0:NextSequenceNumber)
#             - Node: ns=1;i=1115, BrowseName: QualifiedName(0:EventQueueOverflowCount)
#         - Node: i=3706, BrowseName: QualifiedName(0:SessionsDiagnosticsSummary)
#           - Node: i=3707, BrowseName: QualifiedName(0:SessionDiagnosticsArray)
#             - Node: ns=1;i=1025, BrowseName: QualifiedName(0:SessionDiagnostics)
#               - Node: ns=1;i=1026, BrowseName: QualifiedName(0:SessionId)
#               - Node: ns=1;i=1027, BrowseName: QualifiedName(0:SessionName)
#               - Node: ns=1;i=1028, BrowseName: QualifiedName(0:ClientDescription)
#               - Node: ns=1;i=1029, BrowseName: QualifiedName(0:ServerUri)
#               - Node: ns=1;i=1030, BrowseName: QualifiedName(0:EndpointUrl)
#               - Node: ns=1;i=1031, BrowseName: QualifiedName(0:LocaleIds)
#               - Node: ns=1;i=1032, BrowseName: QualifiedName(0:ActualSessionTimeout)
#               - Node: ns=1;i=1033, BrowseName: QualifiedName(0:MaxResponseMessageSize)
#               - Node: ns=1;i=1034, BrowseName: QualifiedName(0:ClientConnectionTime)
#               - Node: ns=1;i=1035, BrowseName: QualifiedName(0:ClientLastContactTime)
#               - Node: ns=1;i=1036, BrowseName: QualifiedName(0:CurrentSubscriptionsCount)
#               - Node: ns=1;i=1037, BrowseName: QualifiedName(0:CurrentMonitoredItemsCount)
#               - Node: ns=1;i=1038, BrowseName: QualifiedName(0:CurrentPublishRequestsInQueue)
#               - Node: ns=1;i=1039, BrowseName: QualifiedName(0:TotalRequestCount)
#               - Node: ns=1;i=1040, BrowseName: QualifiedName(0:UnauthorizedRequestCount)
#               - Node: ns=1;i=1041, BrowseName: QualifiedName(0:ReadCount)
#               - Node: ns=1;i=1042, BrowseName: QualifiedName(0:HistoryReadCount)
#               - Node: ns=1;i=1043, BrowseName: QualifiedName(0:WriteCount)
#               - Node: ns=1;i=1044, BrowseName: QualifiedName(0:HistoryUpdateCount)
#               - Node: ns=1;i=1045, BrowseName: QualifiedName(0:CallCount)
#               - Node: ns=1;i=1046, BrowseName: QualifiedName(0:CreateMonitoredItemsCount)
#               - Node: ns=1;i=1047, BrowseName: QualifiedName(0:ModifyMonitoredItemsCount)
#               - Node: ns=1;i=1048, BrowseName: QualifiedName(0:SetMonitoringModeCount)
#               - Node: ns=1;i=1049, BrowseName: QualifiedName(0:SetTriggeringCount)
#               - Node: ns=1;i=1050, BrowseName: QualifiedName(0:DeleteMonitoredItemsCount)
#               - Node: ns=1;i=1051, BrowseName: QualifiedName(0:CreateSubscriptionCount)
#               - Node: ns=1;i=1052, BrowseName: QualifiedName(0:ModifySubscriptionCount)
#               - Node: ns=1;i=1053, BrowseName: QualifiedName(0:SetPublishingModeCount)
#               - Node: ns=1;i=1054, BrowseName: QualifiedName(0:PublishCount)
#               - Node: ns=1;i=1055, BrowseName: QualifiedName(0:RepublishCount)
#               - Node: ns=1;i=1056, BrowseName: QualifiedName(0:TransferSubscriptionsCount)
#               - Node: ns=1;i=1057, BrowseName: QualifiedName(0:DeleteSubscriptionsCount)
#               - Node: ns=1;i=1058, BrowseName: QualifiedName(0:AddNodesCount)
#               - Node: ns=1;i=1059, BrowseName: QualifiedName(0:AddReferencesCount)
#               - Node: ns=1;i=1060, BrowseName: QualifiedName(0:DeleteNodesCount)
#               - Node: ns=1;i=1061, BrowseName: QualifiedName(0:DeleteReferencesCount)
#               - Node: ns=1;i=1062, BrowseName: QualifiedName(0:BrowseCount)
#               - Node: ns=1;i=1063, BrowseName: QualifiedName(0:BrowseNextCount)
#               - Node: ns=1;i=1064, BrowseName: QualifiedName(0:TranslateBrowsePathsToNodeIdsCount)
#               - Node: ns=1;i=1065, BrowseName: QualifiedName(0:QueryFirstCount)
#               - Node: ns=1;i=1066, BrowseName: QualifiedName(0:QueryNextCount)
#               - Node: ns=1;i=1067, BrowseName: QualifiedName(0:RegisterNodesCount)
#               - Node: ns=1;i=1068, BrowseName: QualifiedName(0:UnregisterNodesCount)
#             - Node: ns=1;i=257, BrowseName: QualifiedName(0:SessionDiagnostics)
#               - Node: ns=1;i=258, BrowseName: QualifiedName(0:SessionId)
#               - Node: ns=1;i=259, BrowseName: QualifiedName(0:SessionName)
#               - Node: ns=1;i=260, BrowseName: QualifiedName(0:ClientDescription)
#               - Node: ns=1;i=261, BrowseName: QualifiedName(0:ServerUri)
#               - Node: ns=1;i=262, BrowseName: QualifiedName(0:EndpointUrl)
#               - Node: ns=1;i=263, BrowseName: QualifiedName(0:LocaleIds)
#               - Node: ns=1;i=264, BrowseName: QualifiedName(0:ActualSessionTimeout)
#               - Node: ns=1;i=265, BrowseName: QualifiedName(0:MaxResponseMessageSize)
#               - Node: ns=1;i=266, BrowseName: QualifiedName(0:ClientConnectionTime)
#               - Node: ns=1;i=267, BrowseName: QualifiedName(0:ClientLastContactTime)
#               - Node: ns=1;i=268, BrowseName: QualifiedName(0:CurrentSubscriptionsCount)
#               - Node: ns=1;i=269, BrowseName: QualifiedName(0:CurrentMonitoredItemsCount)
#               - Node: ns=1;i=270, BrowseName: QualifiedName(0:CurrentPublishRequestsInQueue)
#               - Node: ns=1;i=271, BrowseName: QualifiedName(0:TotalRequestCount)
#               - Node: ns=1;i=272, BrowseName: QualifiedName(0:UnauthorizedRequestCount)
#               - Node: ns=1;i=273, BrowseName: QualifiedName(0:ReadCount)
#               - Node: ns=1;i=274, BrowseName: QualifiedName(0:HistoryReadCount)
#               - Node: ns=1;i=275, BrowseName: QualifiedName(0:WriteCount)
#               - Node: ns=1;i=276, BrowseName: QualifiedName(0:HistoryUpdateCount)
#               - Node: ns=1;i=277, BrowseName: QualifiedName(0:CallCount)
#               - Node: ns=1;i=278, BrowseName: QualifiedName(0:CreateMonitoredItemsCount)
#               - Node: ns=1;i=279, BrowseName: QualifiedName(0:ModifyMonitoredItemsCount)
#               - Node: ns=1;i=280, BrowseName: QualifiedName(0:SetMonitoringModeCount)
#               - Node: ns=1;i=281, BrowseName: QualifiedName(0:SetTriggeringCount)
#               - Node: ns=1;i=282, BrowseName: QualifiedName(0:DeleteMonitoredItemsCount)
#               - Node: ns=1;i=283, BrowseName: QualifiedName(0:CreateSubscriptionCount)
#               - Node: ns=1;i=284, BrowseName: QualifiedName(0:ModifySubscriptionCount)
#               - Node: ns=1;i=285, BrowseName: QualifiedName(0:SetPublishingModeCount)
#               - Node: ns=1;i=286, BrowseName: QualifiedName(0:PublishCount)
#               - Node: ns=1;i=287, BrowseName: QualifiedName(0:RepublishCount)
#               - Node: ns=1;i=288, BrowseName: QualifiedName(0:TransferSubscriptionsCount)
#               - Node: ns=1;i=289, BrowseName: QualifiedName(0:DeleteSubscriptionsCount)
#               - Node: ns=1;i=290, BrowseName: QualifiedName(0:AddNodesCount)
#               - Node: ns=1;i=291, BrowseName: QualifiedName(0:AddReferencesCount)
#               - Node: ns=1;i=292, BrowseName: QualifiedName(0:DeleteNodesCount)
#               - Node: ns=1;i=293, BrowseName: QualifiedName(0:DeleteReferencesCount)
#               - Node: ns=1;i=294, BrowseName: QualifiedName(0:BrowseCount)
#               - Node: ns=1;i=295, BrowseName: QualifiedName(0:BrowseNextCount)
#               - Node: ns=1;i=296, BrowseName: QualifiedName(0:TranslateBrowsePathsToNodeIdsCount)
#               - Node: ns=1;i=297, BrowseName: QualifiedName(0:QueryFirstCount)
#               - Node: ns=1;i=298, BrowseName: QualifiedName(0:QueryNextCount)
#               - Node: ns=1;i=299, BrowseName: QualifiedName(0:RegisterNodesCount)
#               - Node: ns=1;i=300, BrowseName: QualifiedName(0:UnregisterNodesCount)
#             - Node: ns=1;i=769, BrowseName: QualifiedName(0:SessionDiagnostics)
#               - Node: ns=1;i=770, BrowseName: QualifiedName(0:SessionId)
#               - Node: ns=1;i=771, BrowseName: QualifiedName(0:SessionName)
#               - Node: ns=1;i=772, BrowseName: QualifiedName(0:ClientDescription)
#               - Node: ns=1;i=773, BrowseName: QualifiedName(0:ServerUri)
#               - Node: ns=1;i=774, BrowseName: QualifiedName(0:EndpointUrl)
#               - Node: ns=1;i=775, BrowseName: QualifiedName(0:LocaleIds)
#               - Node: ns=1;i=776, BrowseName: QualifiedName(0:ActualSessionTimeout)
#               - Node: ns=1;i=777, BrowseName: QualifiedName(0:MaxResponseMessageSize)
#               - Node: ns=1;i=778, BrowseName: QualifiedName(0:ClientConnectionTime)
#               - Node: ns=1;i=779, BrowseName: QualifiedName(0:ClientLastContactTime)
#               - Node: ns=1;i=780, BrowseName: QualifiedName(0:CurrentSubscriptionsCount)
#               - Node: ns=1;i=781, BrowseName: QualifiedName(0:CurrentMonitoredItemsCount)
#               - Node: ns=1;i=782, BrowseName: QualifiedName(0:CurrentPublishRequestsInQueue)
#               - Node: ns=1;i=783, BrowseName: QualifiedName(0:TotalRequestCount)
#               - Node: ns=1;i=784, BrowseName: QualifiedName(0:UnauthorizedRequestCount)
#               - Node: ns=1;i=785, BrowseName: QualifiedName(0:ReadCount)
#               - Node: ns=1;i=786, BrowseName: QualifiedName(0:HistoryReadCount)
#               - Node: ns=1;i=787, BrowseName: QualifiedName(0:WriteCount)
#               - Node: ns=1;i=788, BrowseName: QualifiedName(0:HistoryUpdateCount)
#               - Node: ns=1;i=789, BrowseName: QualifiedName(0:CallCount)
#               - Node: ns=1;i=790, BrowseName: QualifiedName(0:CreateMonitoredItemsCount)
#               - Node: ns=1;i=791, BrowseName: QualifiedName(0:ModifyMonitoredItemsCount)
#               - Node: ns=1;i=792, BrowseName: QualifiedName(0:SetMonitoringModeCount)
#               - Node: ns=1;i=793, BrowseName: QualifiedName(0:SetTriggeringCount)
#               - Node: ns=1;i=794, BrowseName: QualifiedName(0:DeleteMonitoredItemsCount)
#               - Node: ns=1;i=795, BrowseName: QualifiedName(0:CreateSubscriptionCount)
#               - Node: ns=1;i=796, BrowseName: QualifiedName(0:ModifySubscriptionCount)
#               - Node: ns=1;i=797, BrowseName: QualifiedName(0:SetPublishingModeCount)
#               - Node: ns=1;i=798, BrowseName: QualifiedName(0:PublishCount)
#               - Node: ns=1;i=799, BrowseName: QualifiedName(0:RepublishCount)
#               - Node: ns=1;i=800, BrowseName: QualifiedName(0:TransferSubscriptionsCount)
#               - Node: ns=1;i=801, BrowseName: QualifiedName(0:DeleteSubscriptionsCount)
#               - Node: ns=1;i=802, BrowseName: QualifiedName(0:AddNodesCount)
#               - Node: ns=1;i=803, BrowseName: QualifiedName(0:AddReferencesCount)
#               - Node: ns=1;i=804, BrowseName: QualifiedName(0:DeleteNodesCount)
#               - Node: ns=1;i=805, BrowseName: QualifiedName(0:DeleteReferencesCount)
#               - Node: ns=1;i=806, BrowseName: QualifiedName(0:BrowseCount)
#               - Node: ns=1;i=807, BrowseName: QualifiedName(0:BrowseNextCount)
#               - Node: ns=1;i=808, BrowseName: QualifiedName(0:TranslateBrowsePathsToNodeIdsCount)
#               - Node: ns=1;i=809, BrowseName: QualifiedName(0:QueryFirstCount)
#               - Node: ns=1;i=810, BrowseName: QualifiedName(0:QueryNextCount)
#               - Node: ns=1;i=811, BrowseName: QualifiedName(0:RegisterNodesCount)
#               - Node: ns=1;i=812, BrowseName: QualifiedName(0:UnregisterNodesCount)
#             - Node: ns=1;i=513, BrowseName: QualifiedName(0:SessionDiagnostics)
#               - Node: ns=1;i=514, BrowseName: QualifiedName(0:SessionId)
#               - Node: ns=1;i=515, BrowseName: QualifiedName(0:SessionName)
#               - Node: ns=1;i=516, BrowseName: QualifiedName(0:ClientDescription)
#               - Node: ns=1;i=517, BrowseName: QualifiedName(0:ServerUri)
#               - Node: ns=1;i=518, BrowseName: QualifiedName(0:EndpointUrl)
#               - Node: ns=1;i=519, BrowseName: QualifiedName(0:LocaleIds)
#               - Node: ns=1;i=520, BrowseName: QualifiedName(0:ActualSessionTimeout)
#               - Node: ns=1;i=521, BrowseName: QualifiedName(0:MaxResponseMessageSize)
#               - Node: ns=1;i=522, BrowseName: QualifiedName(0:ClientConnectionTime)
#               - Node: ns=1;i=523, BrowseName: QualifiedName(0:ClientLastContactTime)
#               - Node: ns=1;i=524, BrowseName: QualifiedName(0:CurrentSubscriptionsCount)
#               - Node: ns=1;i=525, BrowseName: QualifiedName(0:CurrentMonitoredItemsCount)
#               - Node: ns=1;i=526, BrowseName: QualifiedName(0:CurrentPublishRequestsInQueue)
#               - Node: ns=1;i=527, BrowseName: QualifiedName(0:TotalRequestCount)
#               - Node: ns=1;i=528, BrowseName: QualifiedName(0:UnauthorizedRequestCount)
#               - Node: ns=1;i=529, BrowseName: QualifiedName(0:ReadCount)
#               - Node: ns=1;i=530, BrowseName: QualifiedName(0:HistoryReadCount)
#               - Node: ns=1;i=531, BrowseName: QualifiedName(0:WriteCount)
#               - Node: ns=1;i=532, BrowseName: QualifiedName(0:HistoryUpdateCount)
#               - Node: ns=1;i=533, BrowseName: QualifiedName(0:CallCount)
#               - Node: ns=1;i=534, BrowseName: QualifiedName(0:CreateMonitoredItemsCount)
#               - Node: ns=1;i=535, BrowseName: QualifiedName(0:ModifyMonitoredItemsCount)
#               - Node: ns=1;i=536, BrowseName: QualifiedName(0:SetMonitoringModeCount)
#               - Node: ns=1;i=537, BrowseName: QualifiedName(0:SetTriggeringCount)
#               - Node: ns=1;i=538, BrowseName: QualifiedName(0:DeleteMonitoredItemsCount)
#               - Node: ns=1;i=539, BrowseName: QualifiedName(0:CreateSubscriptionCount)
#               - Node: ns=1;i=540, BrowseName: QualifiedName(0:ModifySubscriptionCount)
#               - Node: ns=1;i=541, BrowseName: QualifiedName(0:SetPublishingModeCount)
#               - Node: ns=1;i=542, BrowseName: QualifiedName(0:PublishCount)
#               - Node: ns=1;i=543, BrowseName: QualifiedName(0:RepublishCount)
#               - Node: ns=1;i=544, BrowseName: QualifiedName(0:TransferSubscriptionsCount)
#               - Node: ns=1;i=545, BrowseName: QualifiedName(0:DeleteSubscriptionsCount)
#               - Node: ns=1;i=546, BrowseName: QualifiedName(0:AddNodesCount)
#               - Node: ns=1;i=547, BrowseName: QualifiedName(0:AddReferencesCount)
#               - Node: ns=1;i=548, BrowseName: QualifiedName(0:DeleteNodesCount)
#               - Node: ns=1;i=549, BrowseName: QualifiedName(0:DeleteReferencesCount)
#               - Node: ns=1;i=550, BrowseName: QualifiedName(0:BrowseCount)
#               - Node: ns=1;i=551, BrowseName: QualifiedName(0:BrowseNextCount)
#               - Node: ns=1;i=552, BrowseName: QualifiedName(0:TranslateBrowsePathsToNodeIdsCount)
#               - Node: ns=1;i=553, BrowseName: QualifiedName(0:QueryFirstCount)
#               - Node: ns=1;i=554, BrowseName: QualifiedName(0:QueryNextCount)
#               - Node: ns=1;i=555, BrowseName: QualifiedName(0:RegisterNodesCount)
#               - Node: ns=1;i=556, BrowseName: QualifiedName(0:UnregisterNodesCount)
#           - Node: i=3708, BrowseName: QualifiedName(0:SessionSecurityDiagnosticsArray)
#             - Node: ns=1;i=1069, BrowseName: QualifiedName(0:SessionSecurityDiagnostics)
#               - Node: ns=1;i=1070, BrowseName: QualifiedName(0:SessionId)
#               - Node: ns=1;i=1071, BrowseName: QualifiedName(0:ClientUserIdOfSession)
#               - Node: ns=1;i=1072, BrowseName: QualifiedName(0:ClientUserIdHistory)
#               - Node: ns=1;i=1073, BrowseName: QualifiedName(0:AuthenticationMechanism)
#               - Node: ns=1;i=1074, BrowseName: QualifiedName(0:Encoding)
#               - Node: ns=1;i=1075, BrowseName: QualifiedName(0:TransportProtocol)
#               - Node: ns=1;i=1076, BrowseName: QualifiedName(0:SecurityMode)
#               - Node: ns=1;i=1077, BrowseName: QualifiedName(0:SecurityPolicyUri)
#               - Node: ns=1;i=1078, BrowseName: QualifiedName(0:ClientCertificate)
#             - Node: ns=1;i=301, BrowseName: QualifiedName(0:SessionSecurityDiagnostics)
#               - Node: ns=1;i=302, BrowseName: QualifiedName(0:SessionId)
#               - Node: ns=1;i=303, BrowseName: QualifiedName(0:ClientUserIdOfSession)
#               - Node: ns=1;i=304, BrowseName: QualifiedName(0:ClientUserIdHistory)
#               - Node: ns=1;i=305, BrowseName: QualifiedName(0:AuthenticationMechanism)
#               - Node: ns=1;i=306, BrowseName: QualifiedName(0:Encoding)
#               - Node: ns=1;i=307, BrowseName: QualifiedName(0:TransportProtocol)
#               - Node: ns=1;i=308, BrowseName: QualifiedName(0:SecurityMode)
#               - Node: ns=1;i=309, BrowseName: QualifiedName(0:SecurityPolicyUri)
#               - Node: ns=1;i=310, BrowseName: QualifiedName(0:ClientCertificate)
#             - Node: ns=1;i=813, BrowseName: QualifiedName(0:SessionSecurityDiagnostics)
#               - Node: ns=1;i=814, BrowseName: QualifiedName(0:SessionId)
#               - Node: ns=1;i=815, BrowseName: QualifiedName(0:ClientUserIdOfSession)
#               - Node: ns=1;i=816, BrowseName: QualifiedName(0:ClientUserIdHistory)
#               - Node: ns=1;i=817, BrowseName: QualifiedName(0:AuthenticationMechanism)
#               - Node: ns=1;i=818, BrowseName: QualifiedName(0:Encoding)
#               - Node: ns=1;i=819, BrowseName: QualifiedName(0:TransportProtocol)
#               - Node: ns=1;i=820, BrowseName: QualifiedName(0:SecurityMode)
#               - Node: ns=1;i=821, BrowseName: QualifiedName(0:SecurityPolicyUri)
#               - Node: ns=1;i=822, BrowseName: QualifiedName(0:ClientCertificate)
#             - Node: ns=1;i=557, BrowseName: QualifiedName(0:SessionSecurityDiagnostics)
#               - Node: ns=1;i=558, BrowseName: QualifiedName(0:SessionId)
#               - Node: ns=1;i=559, BrowseName: QualifiedName(0:ClientUserIdOfSession)
#               - Node: ns=1;i=560, BrowseName: QualifiedName(0:ClientUserIdHistory)
#               - Node: ns=1;i=561, BrowseName: QualifiedName(0:AuthenticationMechanism)
#               - Node: ns=1;i=562, BrowseName: QualifiedName(0:Encoding)
#               - Node: ns=1;i=563, BrowseName: QualifiedName(0:TransportProtocol)
# ...
# Level: 14, BrowseName: QualifiedName(2:strName), NodeId: StringNodeId(ns=2;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=plc/app/Station1/sym/OrderManagement/ns=2;s=plc/app/Station1/sym/OrderManagement/arQualityParameters/5/strName)
# Level: 14, BrowseName: QualifiedName(2:strName), NodeId: StringNodeId(ns=2;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=plc/app/Station1/sym/OrderManagement/ns=2;s=plc/app/Station1/sym/OrderManagement/arQualityParameters/6/strName)
# Level: 14, BrowseName: QualifiedName(2:strName), NodeId: StringNodeId(ns=2;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=plc/app/Station1/sym/OrderManagement/ns=2;s=plc/app/Station1/sym/OrderManagement/arQualityParameters/7/strName)
# Level: 14, BrowseName: QualifiedName(2:strName), NodeId: StringNodeId(ns=2;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=plc/app/Station1/sym/OrderManagement/ns=2;s=plc/app/Station1/sym/OrderManagement/arQualityParameters/8/strName)
# Level: 14, BrowseName: QualifiedName(2:strName), NodeId: StringNodeId(ns=2;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=plc/app/Station1/sym/OrderManagement/ns=2;s=plc/app/Station1/sym/OrderManagement/arQualityParameters/9/strName)
# Level: 14, BrowseName: QualifiedName(2:strTarget), NodeId: StringNodeId(ns=2;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=plc/app/Station1/sym/OrderManagement/ns=2;s=plc/app/Station1/sym/OrderManagement/arQualityParameters/1/strTarget)
# Level: 14, BrowseName: QualifiedName(2:strTarget), NodeId: StringNodeId(ns=2;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=plc/app/Station1/sym/OrderManagement/ns=2;s=plc/app/Station1/sym/OrderManagement/arQualityParameters/10/strTarget)
# Level: 14, BrowseName: QualifiedName(2:strTarget), NodeId: StringNodeId(ns=2;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=plc/app/Station1/sym/OrderManagement/ns=2;s=plc/app/Station1/sym/OrderManagement/arQualityParameters/2/strTarget)
# Level: 14, BrowseName: QualifiedName(2:strTarget), NodeId: StringNodeId(ns=2;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=plc/app/Station1/sym/OrderManagement/ns=2;s=plc/app/Station1/sym/OrderManagement/arQualityParameters/3/strTarget)
# Level: 14, BrowseName: QualifiedName(2:strTarget), NodeId: StringNodeId(ns=2;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=plc/app/Station1/sym/OrderManagement/ns=2;s=plc/app/Station1/sym/OrderManagement/arQualityParameters/4/strTarget)
# Level: 14, BrowseName: QualifiedName(2:strTarget), NodeId: StringNodeId(ns=2;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=plc/app/Station1/sym/OrderManagement/ns=2;s=plc/app/Station1/sym/OrderManagement/arQualityParameters/5/strTarget)
# Level: 14, BrowseName: QualifiedName(2:strTarget), NodeId: StringNodeId(ns=2;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=plc/app/Station1/sym/OrderManagement/ns=2;s=plc/app/Station1/sym/OrderManagement/arQualityParameters/6/strTarget)
# Level: 14, BrowseName: QualifiedName(2:strTarget), NodeId: StringNodeId(ns=2;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=plc/app/Station1/sym/OrderManagement/ns=2;s=plc/app/Station1/sym/OrderManagement/arQualityParameters/7/strTarget)
# Level: 14, BrowseName: QualifiedName(2:strTarget), NodeId: StringNodeId(ns=2;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=plc/app/Station1/sym/OrderManagement/ns=2;s=plc/app/Station1/sym/OrderManagement/arQualityParameters/8/strTarget)
# Level: 14, BrowseName: QualifiedName(2:strTarget), NodeId: StringNodeId(ns=2;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=plc/app/Station1/sym/OrderManagement/ns=2;s=plc/app/Station1/sym/OrderManagement/arQualityParameters/9/strTarget)
# Level: 14, BrowseName: QualifiedName(2:strValue), NodeId: StringNodeId(ns=2;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=plc/app/Station1/sym/OrderManagement/ns=2;s=plc/app/Station1/sym/OrderManagement/arQualityParameters/1/strValue)
# Level: 14, BrowseName: QualifiedName(2:strValue), NodeId: StringNodeId(ns=2;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=plc/app/Station1/sym/OrderManagement/ns=2;s=plc/app/Station1/sym/OrderManagement/arQualityParameters/10/strValue)
# Level: 14, BrowseName: QualifiedName(2:strValue), NodeId: StringNodeId(ns=2;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=plc/app/Station1/sym/OrderManagement/ns=2;s=plc/app/Station1/sym/OrderManagement/arQualityParameters/2/strValue)
# Level: 14, BrowseName: QualifiedName(2:strValue), NodeId: StringNodeId(ns=2;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=plc/app/Station1/sym/OrderManagement/ns=2;s=plc/app/Station1/sym/OrderManagement/arQualityParameters/3/strValue)
# Level: 14, BrowseName: QualifiedName(2:strValue), NodeId: StringNodeId(ns=2;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=plc/app/Station1/sym/OrderManagement/ns=2;s=plc/app/Station1/sym/OrderManagement/arQualityParameters/4/strValue)
# Level: 14, BrowseName: QualifiedName(2:strValue), NodeId: StringNodeId(ns=2;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=plc/app/Station1/sym/OrderManagement/ns=2;s=plc/app/Station1/sym/OrderManagement/arQualityParameters/5/strValue)
# Level: 14, BrowseName: QualifiedName(2:strValue), NodeId: StringNodeId(ns=2;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=plc/app/Station1/sym/OrderManagement/ns=2;s=plc/app/Station1/sym/OrderManagement/arQualityParameters/6/strValue)
# Level: 14, BrowseName: QualifiedName(2:strValue), NodeId: StringNodeId(ns=2;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=plc/app/Station1/sym/OrderManagement/ns=2;s=plc/app/Station1/sym/OrderManagement/arQualityParameters/7/strValue)
# Level: 14, BrowseName: QualifiedName(2:strValue), NodeId: StringNodeId(ns=2;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=plc/app/Station1/sym/OrderManagement/ns=2;s=plc/app/Station1/sym/OrderManagement/arQualityParameters/8/strValue)
# Level: 14, BrowseName: QualifiedName(2:strValue), NodeId: StringNodeId(ns=2;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=plc/app/Station1/sym/OrderManagement/ns=2;s=plc/app/Station1/sym/OrderManagement/arQualityParameters/9/strValue)
# Level: 14, BrowseName: QualifiedName(2:values), NodeId: StringNodeId(ns=2;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=scheduler/tasks/ctrlXAutomation/info/common-data-rt/histogram/values/ns=2;s=scheduler/tasks/ctrlXAutomation/info/common-data-rt/histogram/values)
# Level: 14, BrowseName: QualifiedName(2:values), NodeId: StringNodeId(ns=2;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=scheduler/tasks/ctrlXAutomation/info/duration-rt/histogram/values/ns=2;s=scheduler/tasks/ctrlXAutomation/info/duration-rt/histogram/values)
# Level: 14, BrowseName: QualifiedName(2:values), NodeId: StringNodeId(ns=2;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=scheduler/tasks/motionHighPrep/info/common-data-rt/histogram/values/ns=2;s=scheduler/tasks/motionHighPrep/info/common-data-rt/histogram/values)
# Level: 14, BrowseName: QualifiedName(2:values), NodeId: StringNodeId(ns=2;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=scheduler/tasks/motionHighPrep/info/duration-rt/histogram/values/ns=2;s=scheduler/tasks/motionHighPrep/info/duration-rt/histogram/values)
# Level: 14, BrowseName: QualifiedName(2:values), NodeId: StringNodeId(ns=2;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=scheduler/tasks/schedBackground/info/common-data-rt/histogram/values/ns=2;s=scheduler/tasks/schedBackground/info/common-data-rt/histogram/values)
# Level: 14, BrowseName: QualifiedName(2:values), NodeId: StringNodeId(ns=2;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=scheduler/tasks/schedBackground/info/duration-rt/histogram/values/ns=2;s=scheduler/tasks/schedBackground/info/duration-rt/histogram/values)
# Level: 14, BrowseName: QualifiedName(8:acs), NodeId: StringNodeId(ns=8;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=types/ns=3;s=types/motion/kin/state/values/actual/pos/acs)
# Level: 14, BrowseName: QualifiedName(8:acs), NodeId: StringNodeId(ns=8;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=types/ns=3;s=types/motion/kin/state/values/ipo/pos/acs)
# Level: 14, BrowseName: QualifiedName(8:active), NodeId: StringNodeId(ns=8;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=motion/state/functions/somo/rt-data/signals_in/histogram/active)
# Level: 14, BrowseName: QualifiedName(8:active), NodeId: StringNodeId(ns=8;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=motion/state/functions/somo/rt-data/signals_out/histogram/active)
# Level: 14, BrowseName: QualifiedName(8:axis-assignment), NodeId: StringNodeId(ns=8;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=types/ns=3;s=types/motion/kin/cfg/coord-systems/mcs/param/axis-assignment)
# Level: 14, BrowseName: QualifiedName(8:axis-offsets), NodeId: StringNodeId(ns=8;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=types/ns=3;s=types/motion/kin/cfg/coord-systems/mcs/param/axis-offsets)
# Level: 14, BrowseName: QualifiedName(8:calculation-pipeline), NodeId: StringNodeId(ns=8;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=types/ns=3;s=types/motion/axs/cfg/functions/coupling/sync-motion/calculation-pipeline)
# Level: 14, BrowseName: QualifiedName(8:calculation-pipeline), NodeId: StringNodeId(ns=8;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=types/ns=3;s=types/motion/axs/state/functions/coupling/sync-motion/calculation-pipeline)
# Level: 14, BrowseName: QualifiedName(8:dyn-synchronisation), NodeId: StringNodeId(ns=8;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=types/ns=3;s=types/motion/axs/cfg/functions/coupling/sync-motion/dyn-synchronisation)
# Level: 14, BrowseName: QualifiedName(8:error-reaction), NodeId: StringNodeId(ns=8;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=types/ns=3;s=types/motion/axs/cfg/functions/coupling/sync-motion/error-reaction)
# Level: 14, BrowseName: QualifiedName(8:flexprofiles), NodeId: StringNodeId(ns=8;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=types/ns=3;s=types/motion/axs/cfg/functions/coupling/sync-motion/flexprofiles)
# Level: 14, BrowseName: QualifiedName(8:groups), NodeId: StringNodeId(ns=8;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=types/ns=3;s=types/motion/kin/cfg/coord-systems/mcs/param/groups)
# Level: 14, BrowseName: QualifiedName(8:mcs), NodeId: StringNodeId(ns=8;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=types/ns=3;s=types/motion/kin/state/values/actual/pos/mcs)
# Level: 14, BrowseName: QualifiedName(8:mcs), NodeId: StringNodeId(ns=8;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=types/ns=3;s=types/motion/kin/state/values/ipo/pos/mcs)
# Level: 14, BrowseName: QualifiedName(8:pcs), NodeId: StringNodeId(ns=8;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=types/ns=3;s=types/motion/kin/state/values/actual/pos/pcs)
# Level: 14, BrowseName: QualifiedName(8:pcs), NodeId: StringNodeId(ns=8;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=types/ns=3;s=types/motion/kin/state/values/ipo/pos/pcs)
# Level: 14, BrowseName: QualifiedName(8:stats), NodeId: StringNodeId(ns=8;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=motion/state/functions/somo/rt-data/signals_in/histogram/stats)
# Level: 14, BrowseName: QualifiedName(8:stats), NodeId: StringNodeId(ns=8;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=motion/state/functions/somo/rt-data/signals_out/histogram/stats)
# Level: 14, BrowseName: QualifiedName(8:values), NodeId: StringNodeId(ns=8;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=motion/state/functions/somo/rt-data/signals_in/histogram/values)
# Level: 14, BrowseName: QualifiedName(8:values), NodeId: StringNodeId(ns=8;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=motion/state/functions/somo/rt-data/signals_out/histogram/values)
# Level: 14, BrowseName: QualifiedName(8:wcs), NodeId: StringNodeId(ns=8;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=types/ns=3;s=types/motion/kin/state/values/actual/pos/wcs)
# Level: 14, BrowseName: QualifiedName(8:wcs), NodeId: StringNodeId(ns=8;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=types/ns=3;s=types/motion/kin/state/values/ipo/pos/wcs)
# Level: 15, BrowseName: QualifiedName(2:active), NodeId: StringNodeId(ns=2;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=motion/state/functions/somo/rt-data/signals_in/histogram/active/ns=2;s=motion/state/functions/somo/rt-data/signals_in/histogram/active)
# Level: 15, BrowseName: QualifiedName(2:active), NodeId: StringNodeId(ns=2;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=motion/state/functions/somo/rt-data/signals_out/histogram/active/ns=2;s=motion/state/functions/somo/rt-data/signals_out/histogram/active)
# Level: 15, BrowseName: QualifiedName(2:stats), NodeId: StringNodeId(ns=2;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=motion/state/functions/somo/rt-data/signals_in/histogram/stats/ns=2;s=motion/state/functions/somo/rt-data/signals_in/histogram/stats)
# Level: 15, BrowseName: QualifiedName(2:stats), NodeId: StringNodeId(ns=2;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=motion/state/functions/somo/rt-data/signals_out/histogram/stats/ns=2;s=motion/state/functions/somo/rt-data/signals_out/histogram/stats)
# Level: 15, BrowseName: QualifiedName(2:values), NodeId: StringNodeId(ns=2;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=motion/state/functions/somo/rt-data/signals_in/histogram/values/ns=2;s=motion/state/functions/somo/rt-data/signals_in/histogram/values)
# Level: 15, BrowseName: QualifiedName(2:values), NodeId: StringNodeId(ns=2;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=motion/state/functions/somo/rt-data/signals_out/histogram/values/ns=2;s=motion/state/functions/somo/rt-data/signals_out/histogram/values)
# Level: 15, BrowseName: QualifiedName(8:lim), NodeId: StringNodeId(ns=8;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=types/ns=3;s=types/motion/axs/cfg/functions/coupling/sync-motion/dyn-synchronisation/lim)
# Level: 15, BrowseName: QualifiedName(8:pargroup), NodeId: StringNodeId(ns=8;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=types/ns=3;s=types/motion/kin/cfg/coord-systems/mcs/param/groups/pargroup)
# Level: 15, BrowseName: QualifiedName(8:slave-limits-exceeded), NodeId: StringNodeId(ns=8;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=types/ns=3;s=types/motion/axs/cfg/functions/coupling/sync-motion/error-reaction/slave-limits-exceeded)
# Level: 15, BrowseName: QualifiedName(8:steps), NodeId: StringNodeId(ns=8;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=types/ns=3;s=types/motion/axs/cfg/functions/coupling/sync-motion/calculation-pipeline/steps)
# Level: 15, BrowseName: QualifiedName(8:steps), NodeId: StringNodeId(ns=8;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=types/ns=3;s=types/motion/axs/state/functions/coupling/sync-motion/calculation-pipeline/steps)
# Level: 15, BrowseName: QualifiedName(8:steps-all), NodeId: StringNodeId(ns=8;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=types/ns=3;s=types/motion/axs/cfg/functions/coupling/sync-motion/calculation-pipeline/steps-all)
# Level: 15, BrowseName: QualifiedName(8:validation), NodeId: StringNodeId(ns=8;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=types/ns=3;s=types/motion/axs/state/functions/coupling/sync-motion/calculation-pipeline/validation)
# Level: 16, BrowseName: QualifiedName(8:calc-step-name), NodeId: StringNodeId(ns=8;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=types/ns=3;s=types/motion/axs/state/functions/coupling/sync-motion/calculation-pipeline/steps/calc-step-name)
# Level: 16, BrowseName: QualifiedName(8:parameter), NodeId: StringNodeId(ns=8;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=types/ns=3;s=types/motion/axs/cfg/functions/coupling/sync-motion/calculation-pipeline/steps/parameter)
# Level: 16, BrowseName: QualifiedName(8:parameter), NodeId: StringNodeId(ns=8;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=types/ns=3;s=types/motion/axs/state/functions/coupling/sync-motion/calculation-pipeline/steps/parameter)
# Level: 16, BrowseName: QualifiedName(8:parameter-all), NodeId: StringNodeId(ns=8;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=types/ns=3;s=types/motion/axs/cfg/functions/coupling/sync-motion/calculation-pipeline/steps/parameter-all)
# Level: 16, BrowseName: QualifiedName(8:parname), NodeId: StringNodeId(ns=8;s=opcuaclient/Station1/i=85/ns=8;i=2000/ns=8;s=types/ns=3;s=types/motion/kin/cfg/coord-systems/mcs/param/groups/pargroup/parname)
#
# Node list has been saved to 'nodos_opcua.json'.
# Disconnected from OPC UA server
